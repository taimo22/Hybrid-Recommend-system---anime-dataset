# %% [markdown]
# # Collaborative Filtering

# %%
# data is from https://www.kaggle.com/CooperUnion/anime-recommendations-database

# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
from surprise import Reader, Dataset, SVD

import warnings; warnings.simplefilter('ignore')



from surprise import Reader, Dataset, SVD
from surprise.model_selection import cross_validate
reader = Reader()
ratings = pd.read_csv('./input/rating.csv')
ratings = ratings.dropna()
ratings.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %%
ratings["anime_id"].nunique()
# Out:
# 11200

# %%
data = Dataset.load_from_df(ratings[['user_id', 'anime_id', 'rating']], reader)
svd = SVD()
cross_validate(svd, data, measures=['RMSE', 'MAE'])
# Out:
# {'test_rmse': array([3.28955846, 3.29040951, 3.29113491, 3.29079773, 3.2902267 ]),
#  'test_mae': array([2.95035964, 2.95168714, 2.95189535, 2.95212547, 2.95110548]),
#  'fit_time': (291.02139258384705,
#   300.0403804779053,
#   294.4403119087219,
#   304.7607340812683,
#   309.06429147720337),
#  'test_time': (17.916151762008667,
#   19.285151720046997,
#   18.354126930236816,
#   18.301060676574707,
#   18.295573234558105)}

# %%
trainset = data.build_full_trainset()
svd.fit(trainset)

# %%
svd.predict(1, 9, 1)
# Out:
# Prediction(uid=1, iid=9, r_ui=1, est=2.3843303947105943, details={'was_impossible': False})

# %%
ratings[ratings['user_id'] == 1]
# Out:
#      user_id  anime_id  rating
# 0          1        20      -1
# 1          1        24      -1
# 2          1        79      -1
# 3          1       226      -1
# 4          1       241      -1
# ..       ...       ...     ...
# 148        1     30015      -1
# 149        1     30296      -1
# 150        1     30544      -1
# 151        1     31338      -1
# 152        1     31845      -1
#
# [153 rows x 3 columns]

# %% [markdown]
# # Hybrid-content base +Collaborative Filtering

# %%
data1 = pd.read_csv("./input/anime.csv")
data1 = data1.rename({'rating':'AverageRating'}, axis='columns')
anime_id_ratings=set([i for i in ratings.anime_id])     
         
data1 = data1[data1['anime_id'].isin(anime_id_ratings)]

# %%
data1.head(2)
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
#
#                                                genre   type episodes  \
# 0               Drama, Romance, School, Supernatural  Movie        1
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
#
#    AverageRating  members
# 0           9.37   200630
# 1           9.26   793665

# %%
data1 = data1.dropna()
data1.isnull().sum()
# Out:
# anime_id         0
# name             0
# genre            0
# type             0
# episodes         0
# AverageRating    0
# members          0
# dtype: int64

# %%
print(data1["anime_id"].nunique())
data1['genre'] = data1["genre"].apply(lambda x: x.split(","))
data1['genre'] = data1['genre'].apply(lambda x: [str.lower(i.replace(" ", "")) for i in x])
# Out:
# 11162

# %%
data1["soup"] = data1["genre"]+data1["type"].map(lambda x : [x])
data1['soup'] = data1['soup'].apply(lambda x: ' '.join(x))

count = CountVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
count_matrix = count.fit_transform(data1["soup"])
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
indices = pd.Series(data1.index, index=data1['name'])
indices.head(1)
# Out:
# name
# Kimi no Na wa.    0
# dtype: int64

# %%
id_map = pd.read_csv('./input/anime.csv')[["anime_id", "name"]].set_index('name')
id_map.head(1)
# Out:
#                 anime_id
# name
# Kimi no Na wa.     32281

# %%
def hybrid(userId, title):
    idx = indices[title]

    sim_scores = list(enumerate(cosine_sim[int(idx)]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:26]
    anime_indices = [i[0] for i in sim_scores]
    
    
    anime = data1.iloc[anime_indices][["name",'genre', 'AverageRating', 'anime_id', "type"]]
    anime['est'] = anime['anime_id'].apply(lambda x: svd.predict(userId, x).est)
    
    anime = anime.sort_values('est', ascending=False)
    return anime.head(10)

# %%
hybrid(50, 'Kimi no Na wa.')
# Out:
#                                                    name  \
# 2300                         Koi to Senkyo to Chocolate
# 3297                 Koi to Senkyo to Chocolate Special
# 1697  Zutto Mae kara Suki deshita.: Kokuhaku Jikkou ...
# 894                                    Momo e no Tegami
# 3544                               Ace wo Nerae! (1979)
# 2060  Takanashi Rikka Kai: Chuunibyou demo Koi ga Sh...
# 6160                Tokimeki Memorial: Forever With You
# 6156                                    School Days ONA
# 5233                                 To Heart 2 Special
# 3914                         Myself ; Yourself Specials
#
#                                               genre  AverageRating  anime_id  \
# 2300                       [drama, romance, school]           7.30     12175
# 3297                       [drama, romance, school]           7.03     18045
# 1697                              [romance, school]           7.47     31245
# 894                           [drama, supernatural]           7.78     10389
# 3544       [drama, romance, school, shoujo, sports]           6.95       313
# 2060  [comedy, drama, romance, school, sliceoflife]           7.37     19021
# 6160                       [drama, romance, school]           6.24      2179
# 6156                       [drama, romance, school]           6.24       756
# 5233                       [drama, romance, school]           6.52      1624
# 3914                       [drama, romance, school]           6.85     17585
#
#          type  est
# 2300       TV  5.0
# 3297  Special  5.0
# 1697    Movie  5.0
# 894     Movie  5.0
# 3544    Movie  5.0
# 2060    Movie  5.0
# 6160      OVA  5.0
# 6156      ONA  5.0
# 5233  Special  5.0
# 3914  Special  5.0

# %%
hybrid(5, 'Kimi no Na wa.')
# Out:
#                                                    name  \
# 1111              Aura: Maryuuin Kouga Saigo no Tatakai
# 1436                 &quot;Bungaku Shoujo&quot; Memoire
# 894                                    Momo e no Tegami
# 208                       Kokoro ga Sakebitagatterunda.
# 3544                               Ace wo Nerae! (1979)
# 1959                                          Air Movie
# 60                                   Hotarubi no Mori e
# 2060  Takanashi Rikka Kai: Chuunibyou demo Koi ga Sh...
# 6119                                      Shisha no Sho
# 1494                                           Harmonie
#
#                                                genre  AverageRating  anime_id  \
# 1111  [comedy, drama, romance, school, supernatural]           7.67     14669
# 1436                        [drama, romance, school]           7.54      8481
# 894                            [drama, supernatural]           7.78     10389
# 208                         [drama, romance, school]           8.32     28725
# 3544        [drama, romance, school, shoujo, sports]           6.95       313
# 1959                  [drama, romance, supernatural]           7.39       713
# 60            [drama, romance, shoujo, supernatural]           8.61     10408
# 2060   [comedy, drama, romance, school, sliceoflife]           7.37     19021
# 6119                           [drama, supernatural]           6.25      7510
# 1494                   [drama, school, supernatural]           7.52     20903
#
#        type       est
# 1111  Movie  5.000000
# 1436    OVA  5.000000
# 894   Movie  5.000000
# 208   Movie  5.000000
# 3544  Movie  5.000000
# 1959  Movie  5.000000
# 60    Movie  5.000000
# 2060  Movie  4.938089
# 6119  Movie  4.624851
# 1494  Movie  4.571846

# %%
hybrid(5, 'Death Note')
# Out:
#                                                    name  \
# 8984                       Ishii Hisaichi no Dai Seikai
# 9545                               Mikosuri Han-Gekijou
# 4775         Mobile Suit SD Gundam&#039;s Counterattack
# 5469     Scramble Wars: Tsuppashire! Genom Trophy Rally
# 512                                   Carnival Phantasm
# 575                       Goku Sayonara Zetsubou Sensei
# 618              Zan Sayonara Zetsubou Sensei Bangaichi
# 2364                              Genshiken Nidaime OVA
# 8880  Himitsukessha Taka no Tsume The Movie 4: Kaspe...
# 9946  Peeping Life: Tezuka Pro - Tatsunoko Pro Wonde...
#
#                                genre  AverageRating  anime_id type       est
# 8984                [comedy, parody]           5.13     19583  OVA  5.000000
# 9545                [comedy, parody]           5.43     20453  OVA  5.000000
# 4775         [comedy, mecha, parody]           6.64      2306  OVA  5.000000
# 5469                        [parody]           6.45      2466  OVA  5.000000
# 512   [comedy, parody, supernatural]           8.01     10012  OVA  5.000000
# 575         [comedy, parody, school]           7.96      4872  OVA  5.000000
# 618         [comedy, parody, school]           7.94      7044  OVA  5.000000
# 2364   [comedy, parody, sliceoflife]           7.28     19159  OVA  5.000000
# 8880                [comedy, parody]           6.40     30753  OVA  4.645604
# 9946                [comedy, parody]           4.88     22631  OVA  4.522167

# %%
hybrid(7, 'Sword Art Online')
# Out:
#                                                    name  \
# 717                              Shingeki no Kyojin OVA
# 146                 Hunter x Hunter: Greed Island Final
# 1069        Shingeki no Kyojin Movie 1: Guren no Yumiya
# 961        Shingeki no Kyojin Movie 2: Jiyuu no Tsubasa
# 86                                   Shingeki no Kyojin
# 7284              Shinrabanshou: Tenchi Shinmei no Shou
# 3437                           Juushin Enbu: Hero Tales
# 4071  Kekkai Sensen: Soresaemo Saitei de Saikou na Hibi
# 978                                       Kekkai Sensen
# 2617                       Munto: Toki no Kabe wo Koete
#
#                                                   genre  AverageRating  \
# 717       [action, drama, fantasy, shounen, superpower]           7.88
# 146            [action, adventure, shounen, superpower]           8.41
# 1069      [action, drama, fantasy, shounen, superpower]           7.70
# 961       [action, drama, fantasy, shounen, superpower]           7.75
# 86        [action, drama, fantasy, shounen, superpower]           8.54
# 7284                         [action, fantasy, shounen]           5.58
# 3437                         [action, fantasy, shounen]           6.99
# 4071  [action, fantasy, shounen, superpower, superna...           6.80
# 978   [action, fantasy, shounen, superpower, superna...           7.74
# 2617               [action, fantasy, magic, superpower]           7.21
#
#       anime_id     type  est
# 717      18397      OVA    5
# 146        139      OVA    5
# 1069     23775    Movie    5
# 961      23777    Movie    5
# 86       16498       TV    5
# 7284     24719      ONA    5
# 3437      2772       TV    5
# 4071     30915  Special    5
# 978      24439       TV    5
# 2617      1135      OVA    5

# %%
hybrid(20, 'Shingeki no Kyojin')
# Out:
#                                                     name  \
# 294                  Evangelion: 1.0 You Are (Not) Alone
# 10083           Robot Taekwon V 3tan! Sujung Teukgongdae
# 8424                               Dallyeola Majing-ga-X
# 7683                            Super Express Mazinger 7
# 6524   Wakusei Robo Danguard Ace tai Konchuu Robot Gu...
# 6332          Wakusei Robo Danguard Ace: Uchuu Daikaisen
# 6018   Tetsuwan Atom: Kagayakeru Hoshi - Anata wa Aok...
# 4704               UFO Robo Grendizer tai Great Mazinger
# 4541          UFO Robo Grendizer: Akai Yuuhi no Taiketsu
# 10451                                   Syupeo Taegwon V
#
#                          genre  AverageRating  anime_id   type  est
# 294    [action, mecha, sci-fi]           8.21      2759  Movie    5
# 10083  [action, mecha, sci-fi]           4.81     16566  Movie    5
# 8424           [mecha, sci-fi]           4.13     16554  Movie    5
# 7683           [mecha, sci-fi]           5.15      3252  Movie    5
# 6524           [mecha, sci-fi]           6.08      8707  Movie    5
# 6332           [mecha, sci-fi]           6.17      5515  Movie    5
# 6018           [mecha, sci-fi]           6.28     17963  Movie    5
# 4704           [mecha, sci-fi]           6.66      4387  Movie    5
# 4541           [mecha, sci-fi]           6.70      7839  Movie    5
# 10451  [action, mecha, sci-fi]           4.10     16568  Movie    5
